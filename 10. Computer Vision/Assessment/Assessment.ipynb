# %%
import cv2
import glob

# %% [markdown]
# ## 1.
# Load multiple JPG and PNG images from the OpenCV samples dataset
# and validate their $H \times W \times C$ structure.

# %%
#1
import cv2
import glob

files = glob.glob(r"Data\*.jpg") 

print(files)

for file in files:
    img = cv2.imread(file)

    if img is not None:
        print(file, "->", img.shape)
    else:
        print("Cannot load", file)
# Out:
# ['Data\\home.jpg', 'Data\\WindowsLogo.jpg']
# Data\home.jpg -> (384, 512, 3)
# Data\WindowsLogo.jpg -> (240, 320, 3)

# %%
#2
img = cv2.imread(r"Data\home.jpg")
print(f"Original size: {img.shape}")
# Out:
# Original size: (384, 512, 3)

# %%
inter_linear = cv2.resize(img, (800, 800), interpolation=cv2.INTER_LINEAR)
inter_cubic = cv2.resize(img, (800, 800), interpolation=cv2.INTER_CUBIC)

# %%
diff = cv2.absdiff(inter_linear,inter_cubic)

# %%
import matplotlib.pyplot as plt
titles = ["INTER_LINEAR", "INTER_CUBIC", "Pixel Difference"]
images = [inter_linear,inter_cubic, diff]

for i in range(3):
    plt.subplot(1,3, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis("off")

plt.show()

# %%
#3
rotated = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
cv2.imwrite('rotated.jpg', img)

cv2.imshow("90° Clockwise", rotated)
cv2.waitKey(0)       
cv2.destroyAllWindows()

# %%
height, width = img.shape[:2]
center = (width / 2, height / 2)
angle = 45
rotation_matrix = cv2.getRotationMatrix2D(center, angle, scale=1.0)
rotated_image = cv2.warpAffine(img, rotation_matrix, (width, height))
cv2.imshow('Rotated Image', rotated_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#4
# ROI Crop
roi = img[100:300, 150:350]

# Horizontal and Vertical Flip
h_flip = cv2.flip(roi, 1)
v_flip = cv2.flip(roi, 0)

cv2.imshow("gray Image", v_flip)
cv2.waitKey(0)       
cv2.destroyAllWindows()

# %%
cv2.imshow("gray Image", h_flip)
cv2.waitKey(0)       
cv2.destroyAllWindows()

# %%
# 5
# BGR to Grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# BGR to HSV
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
cv2.imshow("gray Image", gray)
cv2.waitKey(0)       
cv2.destroyAllWindows()

# %%
cv2.imshow("My First Image", hsv)
cv2.waitKey(0)       
cv2.destroyAllWindows()
