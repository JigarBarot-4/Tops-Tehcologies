# %% [markdown]
# # Task 1
# Generate AI-Generated Text using Gemini
# ● Use Google’s API to generate AI-based responses.
# ● Deliverable: Python script generating meaningful responses.

# %%
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6Ljd5kgvieoowqZpskrruHpiZ0HHWu27EqTFnkamsgjjw")

prompt = input("Enter your prompt: ")

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print("\nGemini Response:\n")
print(response.text)
# Out:
# Gemini Response:
#
# I do not have a name. I am a large language model, trained by Google.

# %% [markdown]
# # Task 2
# AI-Powered Image Generation using Gemini
#
# Objective:
# Generate an AI-created image using Google's Gemini model.
#
# Prompt Used:
# "A futuristic smart city at sunset, ultra realistic, cinematic lighting, high detail"
#
# Procedure:
#
# 1. Accessed Google Gemini through Google AI Studio.
# 2. Entered a descriptive text prompt.
# 3. Gemini analyzed the prompt and generated an image based on the given description.
# 4. The generated image was downloaded and saved.
#
# Result:
# A high-quality AI-generated image was successfully created from the text prompt using Gemini.

# %% [markdown]
# ![Generated Image June 19, 2026 - 7_59PM.png](<attachment:Generated Image June 19, 2026 - 7_59PM.png>)
