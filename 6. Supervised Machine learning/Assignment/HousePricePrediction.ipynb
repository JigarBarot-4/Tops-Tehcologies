# %% [markdown]
# 1. Perform EDA
# 2. Build a Simple Linear Regression model to predict the Sale price of the house. Use Area as the independent variable
# 3. Build Multiple Linear Regression model to predict Sale price of the house.
# 4. Use dimensionality reduction technique PCA/LDA and build Multiple Linear Regression model to predict Sale price of the house.
# 5. Build a model using Lasso and Ridge regression to reduce model complexity.
# 6. Build an SVR model to predict Sale price of the house.
# 7. Build Decision Tree Regressor to predict Sale price of the house.
# 8. Build Random Forest Regression model to predict Sale price of the house.
# 9. Use GridsearchCV and RandomizedsearchCV for tuning hyperparameters and fit your model on the optimal parameters.
# 10. Model Selection: Evaluate and compare performance of all the models tofindthebest model.

# %% [markdown]
# 1. Perform EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Bangalore.csv")

# %%
df
# Out:
#          Price  Area                         Location  ...  Sofa  Wardrobe  Stadium
# 0     30000000  3340                 JP Nagar Phase 1  ...     0         0        0
# 1      7888000  1045       Dasarahalli on Tumkur Road  ...     0         0        0
# 2      4866000  1179  Kannur on Thanisandra Main Road  ...     0         0        0
# 3      8358000  1675                     Doddanekundi  ...     0         0        0
# 4      6845000  1670                          Kengeri  ...     0         0        0
# ...        ...   ...                              ...  ...   ...       ...      ...
# 6202   5364000   590                       Chandapura  ...     9         9        9
# 6203   8716000  1179                    Kasavanahalli  ...     9         9        9
# 6204   7373000  1143                    Kasavanahalli  ...     9         9        9
# 6205   4985000  1680                    Kasavanahalli  ...     9         9        9
# ...

# %%
df.shape
# Out:
# (6207, 40)

# %%
df.isnull().sum()
# Out:
# Price                  0
# Area                   0
# Location               0
# No. of Bedrooms        0
# Resale                 0
# MaintenanceStaff       0
# Gymnasium              0
# SwimmingPool           0
# LandscapedGardens      0
# JoggingTrack           0
# RainWaterHarvesting    0
# IndoorGames            0
# ShoppingMall           0
# Intercom               0
# SportsFacility         0
# ATM                    0
# ClubHouse              0
# School                 0
# 24X7Security           0
# PowerBackup            0
# CarParking             0
# StaffQuarter           0
# Cafeteria              0
# MultipurposeRoom       0
# Hospital               0
# WashingMachine         0
# Gasconnection          0
# AC                     0
# Wifi                   0
# Children'splayarea     0
# LiftAvailable          0
# BED                    0
# VaastuCompliant        0
# Microwave              0
# GolfCourse             0
# TV                     0
# DiningTable            0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6207 entries, 0 to 6206
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Price                6207 non-null   int64
#  1   Area                 6207 non-null   int64
#  2   Location             6207 non-null   object
#  3   No. of Bedrooms      6207 non-null   int64
#  4   Resale               6207 non-null   int64
#  5   MaintenanceStaff     6207 non-null   int64
#  6   Gymnasium            6207 non-null   int64
#  7   SwimmingPool         6207 non-null   int64
#  8   LandscapedGardens    6207 non-null   int64
#  9   JoggingTrack         6207 non-null   int64
#  10  RainWaterHarvesting  6207 non-null   int64
#  11  IndoorGames          6207 non-null   int64
#  12  ShoppingMall         6207 non-null   int64
#  13  Intercom             6207 non-null   int64
#  14  SportsFacility       6207 non-null   int64
# ...

# %%
df.describe()
# Out:
#               Price         Area  ...     Wardrobe      Stadium
# count  6.207000e+03  6207.000000  ...  6207.000000  6207.000000
# mean   1.058510e+07  1526.094248  ...     6.171097     6.210569
# std    1.410943e+07   764.845609  ...     4.178546     4.124430
# min    2.000000e+06   415.000000  ...     0.000000     0.000000
# 25%    5.000000e+06  1110.000000  ...     0.000000     0.000000
# 50%    7.368000e+06  1340.000000  ...     9.000000     9.000000
# 75%    1.070000e+07  1662.500000  ...     9.000000     9.000000
# max    3.000000e+08  9900.000000  ...     9.000000     9.000000
#
# [8 rows x 39 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(686)

# %%
df.shape
# Out:
# (6207, 40)

# %%
df = df.drop_duplicates().reset_index(drop = True)

# %%
df.shape
# Out:
# (5521, 40)

# %%
df.nunique()
# Out:
# Price                  2146
# Area                   1359
# Location                302
# No. of Bedrooms           7
# Resale                    2
# MaintenanceStaff          3
# Gymnasium                 3
# SwimmingPool              3
# LandscapedGardens         3
# JoggingTrack              3
# RainWaterHarvesting       3
# IndoorGames               3
# ShoppingMall              3
# Intercom                  3
# SportsFacility            3
# ATM                       3
# ClubHouse                 3
# School                    3
# 24X7Security              3
# PowerBackup               3
# CarParking                3
# StaffQuarter              3
# Cafeteria                 3
# MultipurposeRoom          3
# Hospital                  3
# WashingMachine            3
# Gasconnection             3
# AC                        3
# Wifi                      2
# Children'splayarea        3
# LiftAvailable             3
# BED                       3
# VaastuCompliant           3
# ...

# %%
len(df['Location'].unique())
# Out:
# 302

# %%
important_cols = ['Price', 'Area', 'No. of Bedrooms', 'Resale']
corr = df[important_cols].corr()

# %%
plt.figure(figsize=(15,10))
sns.heatmap(corr,cmap = "coolwarm")
plt.show()

# %%
figure , axes = plt.subplots(2,2)

sns.boxplot(x=df['Price'] , ax=axes[0,0])
axes[0,0].set_title("Price")
sns.boxplot(x=df['Area'] , ax=axes[0,1])
axes[0,1].set_title("Area")
sns.boxplot(x=df['No. of Bedrooms'] , ax=axes[1,0])
axes[1,0].set_title("No. of Bedrooms")
sns.boxplot(x=df['Resale'] , ax=axes[1,1])
axes[1,1].set_title("Resale")

plt.tight_layout()
plt.show()

# %%
print(df['Price'].skew())
print(df['Area'].skew())
# Out:
# 8.190548749839039
# 3.4367809593807883

# %%
df['Price'] = np.log1p(df['Price'])
df['Area'] = np.log1p(df['Area'])

# %%
fig, axes = plt.subplots(1, 3, figsize=(15,5))

sns.boxplot(x=df['Price'], ax=axes[0])
axes[0].set_title('Price')

sns.boxplot(x=df['Area'], ax=axes[1])
axes[1].set_title('Area')

sns.boxplot(x=df['No. of Bedrooms'], ax=axes[2])
axes[2].set_title('Bedrooms')

plt.tight_layout()
plt.show()

# %%
df = df[df['Price'] < df['Price'].quantile(0.99)]
df = df[df['Area'] < df['Area'].quantile(0.99)]

# %%
fig, axes = plt.subplots(1, 3, figsize=(15,5))

sns.boxplot(x=df['Price'], ax=axes[0])
axes[0].set_title('Price')

sns.boxplot(x=df['Area'], ax=axes[1])
axes[1].set_title('Area')

sns.boxplot(x=df['No. of Bedrooms'], ax=axes[2])
axes[2].set_title('Bedrooms')

plt.tight_layout()
plt.show()

# %%
figure , axes = plt.subplots(1,2 , figsize = (15,5))

sns.histplot(df["Price"],ax=axes[0] , kde = True)
sns.histplot(df["Area"],ax=axes[1] , kde = True)

plt.tight_layout()
plt.show()

# %%
sns.scatterplot(x = df['Area'] , y = df["Price"])
plt.title("Area VS Price")
plt.show()

# %%
sns.scatterplot(x = df['No. of Bedrooms'] , y = df["Price"])
plt.title("Bedrooms vs Price") 
plt.show()

# %%
df['Location'].value_counts().head(10).plot(kind='bar')
plt.show()

# %% [markdown]
# 2. Build a Simple Linear Regression model to predict the Sale price of the house. Use Area as the independent variable

# %%
X = df[["Area"]]
y = df[["Price"]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size=0.3 , random_state= 42 )

# %%
from sklearn.linear_model import LinearRegression

# %%
reg =  LinearRegression()
reg.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test , y_pred)

# %%
r2
# Out:
# 0.211503816080869

# %% [markdown]
#  -> The model shows a positive relationship between Area and Price. However, the R² score indicates that Area alone is not sufficient to accurately predict house prices, suggesting that additional features influence house pricing.

# %% [markdown]
# 3. Build Multiple Linear Regression model to predict Sale price of the house.

# %%
df
# Out:
#           Price      Area  ... Wardrobe  Stadium
# 0     17.216708  8.114025  ...        0        0
# 1     15.880853  6.952729  ...        0        0
# 2     15.397783  7.073270  ...        0        0
# 3     15.938730  7.424165  ...        0        0
# 4     15.739029  7.421178  ...        0        0
# ...         ...       ...  ...      ...      ...
# 5516  15.495221  6.381816  ...        9        9
# 5517  15.980671  7.073270  ...        9        9
# 5518  15.813335  7.042286  ...        9        9
# 5519  15.421944  7.427144  ...        9        9
# 5520  16.204273  7.058758  ...        9        9
#
# [5410 rows x 40 columns]

# %%
important_cols
# Out:
# ['Price', 'Area', 'No. of Bedrooms', 'Resale']

# %%
df = pd.read_csv("Bangalore.csv")

# %%
df
# Out:
#          Price  Area                         Location  ...  Sofa  Wardrobe  Stadium
# 0     30000000  3340                 JP Nagar Phase 1  ...     0         0        0
# 1      7888000  1045       Dasarahalli on Tumkur Road  ...     0         0        0
# 2      4866000  1179  Kannur on Thanisandra Main Road  ...     0         0        0
# 3      8358000  1675                     Doddanekundi  ...     0         0        0
# 4      6845000  1670                          Kengeri  ...     0         0        0
# ...        ...   ...                              ...  ...   ...       ...      ...
# 6202   5364000   590                       Chandapura  ...     9         9        9
# 6203   8716000  1179                    Kasavanahalli  ...     9         9        9
# 6204   7373000  1143                    Kasavanahalli  ...     9         9        9
# 6205   4985000  1680                    Kasavanahalli  ...     9         9        9
# ...

# %%
top_locations = df["Location"].value_counts().head(10)

print(top_locations)
# Out:
# Location
# Electronic City Phase 2             232
# RR Nagar                            217
# Begur                               186
# Varthur                             168
# Kumaraswamy Layout                  154
# Attibele                            151
# Narayanapura on Hennur Main Road    148
# Electronic City Phase 1             139
# Harlur                              135
# Krishnarajapura                     131
# Name: count, dtype: int64

# %%
df["Location"] = df["Location"].apply(
    lambda x: x if x in top_locations else "Other"
)

# %%
df = pd.get_dummies(df, columns=["Location"], drop_first=True)

# %%
df
# Out:
#          Price  Area  ...  Location_RR Nagar  Location_Varthur
# 0     30000000  3340  ...              False             False
# 1      7888000  1045  ...              False             False
# 2      4866000  1179  ...              False             False
# 3      8358000  1675  ...              False             False
# 4      6845000  1670  ...              False             False
# ...        ...   ...  ...                ...               ...
# 6202   5364000   590  ...              False             False
# 6203   8716000  1179  ...              False             False
# 6204   7373000  1143  ...              False             False
# 6205   4985000  1680  ...              False             False
# 6206  10900000  1162  ...              False             False
#
# [6207 rows x 49 columns]

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
X
# Out:
#          Price  Area  ...  Location_Other  Location_RR Nagar
# 0     30000000  3340  ...            True              False
# 1      7888000  1045  ...            True              False
# 2      4866000  1179  ...            True              False
# 3      8358000  1675  ...            True              False
# 4      6845000  1670  ...            True              False
# ...        ...   ...  ...             ...                ...
# 6202   5364000   590  ...            True              False
# 6203   8716000  1179  ...            True              False
# 6204   7373000  1143  ...            True              False
# 6205   4985000  1680  ...            True              False
# 6206  10900000  1162  ...            True              False
#
# [6207 rows x 48 columns]

# %%
X_train , y_train , X_test , y_test = train_test_split(X , y , test_size=0.3 ,random_state=42)
